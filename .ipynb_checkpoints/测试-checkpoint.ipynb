# %%
class house(object):
    def __init__(self, city, url, write, host):
        self.city = city
        self.url = url
        self.write = write
        self.host = host
# Out:
# 71
# ['102', '万', '1', '0', '0', '0', '0', '元', '/', '�', 'O']
# ['122', '万', '1', '1', '8', '4', '5', '元', '/', '�', 'O']
# ['120', '万', '1', '1', '8', '8', '1', '元', '/', '�', 'O']
# ['300', '万', '1', '1', '9', '5', '2', '元', '/', '�', 'O']
# ['122', '万', '1', '1', '0', '9', '1', '元', '/', '�', 'O']
# ['124', '万', '1', '3', '3', '3', '3', '元', '/', '�', 'O']
# ['180', '万', '1', '6', '2', '1', '6', '元', '/', '�', 'O']
# ['121', '万', '1', '1', '9', '8', '0', '元', '/', '�', 'O']
# ['520', '万', '2', '6', '9', '4', '3', '元', '/', '�', 'O']
# ['139', '万', '1', '1', '8', '8', '0', '元', '/', '�', 'O']
# ['170', '万', '2', '2', '3', '6', '8', '元', '/', '�', 'O']
# ['170', '万', '1', '6', '3', '8', '7', '元', '/', '�', 'O']
# ['110', '万', '1', '1', '0', '4', '2', '元', '/', '�', 'O']
# ['270', '万', '2', '3', '6', '8', '4', '元', '/', '�', 'O']
# ['62', '万', '1', '3', '7', '7', '8', '元', '/', '�', 'O']
# ['148', '万', '1', '1', '8', '4', '0', '元', '/', '�', 'O']
# ...
